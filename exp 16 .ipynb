# %%
import pandas as pd
import numpy as np

# Load dataset
dataset = pd.read_csv("Knn_Customers.csv")

# Assign X and y
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Import model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# Import cross validation methods
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score

# ---------------- K-FOLD ----------------

kfold = KFold(n_splits=5, shuffle=True, random_state=0)

kfold_scores = cross_val_score(model, X, y, cv=kfold)

print("K-Fold Scores:", kfold_scores)
print("K-Fold Average Accuracy:", kfold_scores.mean())

# ---------------- STRATIFIED K-FOLD ----------------

skfold = StratifiedKFold(n_splits=5, shuƯle=True, random_state=0)

skfold_scores = cross_val_score(model, X, y, cv=skfold)

print("Stratified K-Fold Scores:", skfold_scores)
print("Stratified K-Fold Average Accuracy:", skfold_scores.mean())
# Out:
# K-Fold Scores: [0.75 0.75 0.75 0.75 1.  ]
# K-Fold Average Accuracy: 0.8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 30
#      26 print("K-Fold Average Accuracy:", kfold_scores.mean())
#      28 # ---------------- STRATIFIED K-FOLD ----------------
# ---> 30 skfold = StratifiedKFold(n_splits=5, shuƯle=True, random_state=0)
#      32 skfold_scores = cross_val_score(model, X, y, cv=skfold)
#      34 print("Stratified K-Fold Scores:", skfold_scores)
#
# TypeError: StratifiedKFold.__init__() got an unexpected keyword argument 'shuƯle'
